# %% [markdown]
# <a href="https://colab.research.google.com/github/Ragulan-K/ML-Projects/blob/main/Predicting_LoL_Wins_with_TensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers

# %%
data = pd.read_csv('/content/high_diamond_ranked_10min.csv')

# %%
data.head()
# Out:
#    blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  blueKills  \
# 0         0               28                   2               1          9
# 1         0               12                   1               0          5
# 2         0               15                   0               0          7
# 3         0               43                   1               0          4
# 4         0               75                   4               0          6
#
#    blueDeaths  blueAssists  blueEliteMonsters  blueDragons  blueHeralds  ...  \
# 0           6           11                  0            0            0  ...
# 1           5            5                  0            0            0  ...
# 2          11            4                  1            1            0  ...
# 3           5            5                  1            0            1  ...
# 4           6            6                  0            0            0  ...
#
# ...

# %%
data.shape
# Out:
# (9879, 39)

# %%
data.drop('gameId', axis=1, inplace=True)
